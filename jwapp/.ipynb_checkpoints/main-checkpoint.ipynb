# %%
from jwapp import *

# %%
Student.ping().headers
# Out:
# {'Connection': 'close', 'Cache-Control': 'max-age=0', 'Date': 'Sat, 06 Apr 2024 09:35:10 GMT', 'Expires': 'Sat, 06 Apr 2024 09:35:10 GMT', 'Location': 'http://jwapp.xjtu.edu.cn/app/mobile?token=eyJhbGciOiJIUzUxMiJ9.eyJsb2dpbl91c2VyX2tleSI6InI0aGFoaDVhdnVoNm9vODBhdjY5MHFjMGpmIn0.Glt1D03CecTrCTJfI64VT825_mkmsOzGOCXlJ9pi7kSsGynk95aD6ue6pLFpger1F_40Wn027ZmbcsYh7ymK_w', 'Server': 'wisedu', 'Set-Cookie': 'sk=95812fe656d944f59301865908364769; HttpOnly', 'Content-Length': '0'}

# %%
s = Student(2225015585)
s0 = Student.default()

# %%
print(s.info)
print(s0.info)
# Out:
# {'msg': '操作成功', 'loginOutFlag': 1, 'code': 200, 'xznj': '2022', 'phonenumber': '18875012758', 'usertype': '90001', 'avatar': 'https://jwapp.xjtu.edu.cn/api/image/avatar/2.jpg', 'zymc': '0926理科试验班（物理H）', 'yxmc': '物理学院', 'local': 'zh_CN', 'xh': '2225015585', 'classname': '物试2202', 'xm': '黄得清', 'openDn': '1', 'typeId': '12aa5b5d-3791-4a69-8fda-6e1768da4d97', 'studentstatus': '0'}
# {'msg': '操作成功', 'loginOutFlag': 1, 'code': 200, 'xm': '教务系统管理员', 'openDn': '0', 'phonenumber': None, 'usertype': '10001', 'zgh': '0212020266', 'typeId': '20170323215255143', 'avatar': 'https://jwapp.xjtu.edu.cn/api/image/avatar/default/logo.png', 'yxmc': '教务处', 'local': 'zh_CN'}

# %%
ssa = s.score_statistics_all()
ssa.to_csv("ssa.csv")
ssa
# Out:
#       termCode           termName     gpa credits  currentFlag      tipMsg
# 0            *               全部学期  4.0442      86        False        None
# 1  2023-2024-2   2023-2024学年 第二学期    None    None         True  当前学期暂无统计记录
# 2  2023-2024-1   2023-2024学年 第一学期  4.1534      29        False        None
# 3  2022-2023-4     2022-2023学年 暑假    None    None        False  当前学期暂无统计记录
# 4  2022-2023-3  2022-2023学年 夏季小学期     4.3       1        False        None
# 5  2022-2023-2   2022-2023学年 第二学期  3.9882    25.5        False        None
# 6  2022-2023-1   2022-2023学年 第一学期  3.9787    30.5        False        None

# %%
sa = s.score_all()
sa.to_csv("sa.csv")
sa
# Out:
#                                   id     termCode  \
# 0   0EF346BA2737C475E0636B27F5DBF8D4  2023-2024-1
# 1   0F0DACE705C216BCE0636B27F5DB0B84  2023-2024-1
# 2   0E70F0806D7A70BAE0636A27F5DB2775  2023-2024-1
# 3   0EBC5A0623366E0CE0636A27F5DB0A3E  2023-2024-1
# 4   0EB556C5B13A8E26E0636A27F5DB442E  2023-2024-1
# 5   0CFB59C917D268B6E0636B27F5DBCDF9  2023-2024-1
# 6   0E42B90FE18F4C4EE0636B27F5DB37E3  2023-2024-1
# 7   0E726B8B8BE05EF0E0636A27F5DB9E44  2023-2024-1
# 8   0DBD5AE507E5C04BE0636A27F5DBE045  2023-2024-1
# 9   0ABF5F936BD1463FE0636A27F5DB276A  2023-2024-1
# 10  011EE251BD0B0053E0636A27F5DBF3BA  2022-2023-3
# 11  FF6A9D022D38C5B8E0536A27F5DB516F  2022-2023-2
# 12  FF01102A2B2B10FBE0536A27F5DB5340  2022-2023-2
# 13  FF2E0C21DFC536FAE0536A27F5DBED4E  2022-2023-2
# 14  FF17FA112580FD11E0536A27F5DBCF88  2022-2023-2
# 15  FF199667026F51D8E0536B27F5DBD802  2022-2023-2
# 16  F72FE1EFB8B64DCCE0536B27F5DBC344  2022-2023-2
# 17  FEF4C0CFDBFF2A81E0536B27F5DB365F  2022-2023-2
# ...

# %%
c = s.get_course("概率论")
c
# Out:
# {'id': '0E70F0806D7A70BAE0636A27F5DB2775',
#  'termCode': '2023-2024-1',
#  'courseName': '概率论与数理统计(MATH295507)',
#  'score': '99',
#  'passFlag': True,
#  'coursePoint': '3',
#  'examType': None,
#  'majorFlag': '必修',
#  'examProp': '初修',
#  'replaceFlag': False,
#  'specificReason': None}

# %%
s.score_detail(c)
# Out:
# {'courseName': '概率论与数理统计(MATH295507)',
#  'coursePoint': '3',
#  'examType': '开卷',
#  'majorFlag': '必修',
#  'examProp': '初修',
#  'replaceFlag': False,
#  'score': '99',
#  'gpa': '4.3',
#  'passFlag': True,
#  'specificReason': None,
#  'itemList': [{'itemName': '平时成绩', 'itemPercent': '10%', 'itemScore': '100'},
#   {'itemName': '期末成绩', 'itemPercent': '60%', 'itemScore': '100'},
#   {'itemName': '其他1', 'itemPercent': '30%', 'itemScore': '98'}],
#  'courseList': None,
#  'statusCode': 0}

# %%
a = Address()
a.list()
# Out:
#   contactType objectType    objectId objectName                   path  \
# 0        None       None    teachers         教师      /contact:teachers
# 1        None       None    students         学生      /contact:students
# 2        None       None  teachclass        教学班  /contact:teachclasses
#
#   departmentName majorName className gradeCode personCount
# 0           None      None      None      None       35650
# 1           None      None      None      None      115254
# 2           None      None      None      None           0

# %%
a.reset().goto("学", "2022", "物理学院", "H", "2202")
a.list()
# Out:
#    contactType objectType    objectId objectName  \
# 0     students    student  2204112892        赵鼎熙
# 1     students    student  2204112899        秦兴宇
# 2     students    student  2204112887         高畅
# 3     students    student  2226114150        乔琳木
# 4     students    student  2225015585        黄得清
# 5     students    student  2225113441        王子豪
# 6     students    student  2226114197        刘禹豪
# 7     students    student  2224411556        曹清峰
# 8     students    student  2226114609        邱煜博
# 9     students    student  2226114119        刘满洋
# 10    students    student  2226114428        朱宏坤
# 11    students    student  2224411609        徐锦鹏
# 12    students    student  2225113445        贺昰为
# 13    students    student  2224411621        陈梦凯
# 14    students    student  2226114266        王毅航
# 15    students    student  2224411665        卢嘉祺
# 16    students    student  2203714893        李修齐
# 17    students    student  2221313224        史成宇
# ...

# %%
ids = a.list_id()
ids
# Out:
# ['2204112892',
#  '2204112899',
#  '2204112887',
#  '2226114150',
#  '2225015585',
#  '2225113441',
#  '2226114197',
#  '2224411556',
#  '2226114609',
#  '2226114119',
#  '2226114428',
#  '2224411609',
#  '2225113445',
#  '2224411621',
#  '2226114266',
#  '2224411665',
#  '2203714893',
#  '2221313224',
#  '2223212043',
#  '2223410935',
#  '2223612443',
#  '2224213745',
#  '2225113382',
#  '2226215235']

# %%
sL = StudentList(ids)
ssd = sL.scores_detail("概率论")
ssd.to_csv("ssd.csv")
ssd
# Out:
#             xh   xm score                                           itemList  \
# 0   2204112892  赵鼎熙    94  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 1   2204112899  秦兴宇   100  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 2   2204112887   高畅    91  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 3   2226114150  乔琳木    92  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 4   2225015585  黄得清    99  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 5   2225113441  王子豪    89  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 6   2226114197  刘禹豪    94  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 7   2224411556  曹清峰    99  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 8   2226114609  邱煜博    98  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 9   2226114119  刘满洋    73  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# 10  2226114428  朱宏坤    94  [{'itemName': '平时成绩', 'itemPercent': '10%', 'i...
# ...
