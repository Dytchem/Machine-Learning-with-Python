# %%
import os
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
import paddle

paddle.set_default_dtype("float64")

# %%
def unpickle(file):
    import pickle

    with open(file, "rb") as fo:
        dict = pickle.load(fo, encoding="bytes")
    return dict


def getitem(dict, index):
    label = a[b"labels"][index]
    image_data = a[b"data"][index]
    red_channel = image_data[:1024].reshape((32, 32))
    green_channel = image_data[1024:2048].reshape((32, 32))
    blue_channel = image_data[2048:].reshape((32, 32))
    rgb_image = np.dstack((red_channel, green_channel, blue_channel))
    return rgb_image, label


label_names = unpickle("../data/cifar-10-batches-py/batches.meta")[b"label_names"]

# %%
class Reader(paddle.io.Dataset):
    def __init__(self, *path):
        super().__init__()
        data = unpickle(path[0])
        self.x = data[b"data"] / 255
        self.y = data[b"labels"]
        for i in range(1, len(path)):
            data = unpickle(path[i])
            self.x = np.concatenate((self.x, data[b"data"] / 255))
            self.y = np.concatenate((self.y, data[b"labels"]))

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.y)

# %%
class MyDNN(paddle.nn.Layer):
    def __init__(self):
        super(MyDNN, self).__init__()
        self.fc1 = paddle.nn.Linear(3072, 1024)
        self.relu1 = paddle.nn.ReLU()
        self.fc2 = paddle.nn.Linear(1024, 512)
        self.relu2 = paddle.nn.ReLU()
        self.fc3 = paddle.nn.Linear(512, 256)
        self.relu3 = paddle.nn.ReLU()
        self.fc4 = paddle.nn.Linear(256, 128)
        self.relu4 = paddle.nn.ReLU()
        self.fc5 = paddle.nn.Linear(128, 64)
        self.relu5 = paddle.nn.ReLU()
        self.fc6 = paddle.nn.Linear(64, 32)
        self.relu6 = paddle.nn.ReLU()
        self.fc7 = paddle.nn.Linear(32, 10)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.fc5(x)
        x = self.relu5(x)
        x = self.fc6(x)
        x = self.relu6(x)
        x = self.fc7(x)
        return x

# %%
model = MyDNN()
cross_entropy = paddle.nn.CrossEntropyLoss()
opt = paddle.optimizer.SGD(0.01, model.parameters())

# %%
model.train()
epoch = 10
batch = 10
train_loader = paddle.io.DataLoader(
    Reader(
        "../data/cifar-10-batches-py/data_batch_1",
        "../data/cifar-10-batches-py/data_batch_2",
        "../data/cifar-10-batches-py/data_batch_3",
        "../data/cifar-10-batches-py/data_batch_4",
        "../data/cifar-10-batches-py/data_batch_5",
    ),
    batch_size=batch,
    shuffle=True,
)

for e in range(epoch):
    full_loss = 0
    n_loss = 0
    n_eval = 0
    correct = 0
    for i, (x, y) in enumerate(train_loader):
        if i % 100 == 0:
            print("epoch", e, "\tbatch", i, end=" ")

        y_pred = model(x)
        loss = cross_entropy(y_pred, y)

        loss.backward()
        opt.step()

        full_loss += loss.numpy()
        n_loss += batch
        opt.clear_grad()

        mask = np.array(y_pred, copy=False).argmax(1) == y
        co = mask.sum().numpy()
        correct += co

        if i % 100 == 0:
            print(f"\tloss {loss.numpy():.2f} \taccuracy {co/batch:.2f}")
    print(f"Train Accuracy: {correct/n_loss}%")
    print(f"Epoch: {e}, Loss: {full_loss / n_loss}")
# Out:
# epoch 0 	batch 0 	loss 2.37 	accuracy 0.00
# epoch 0 	batch 100 	loss 2.20 	accuracy 0.20
# epoch 0 	batch 200 	loss 2.28 	accuracy 0.10
# epoch 0 	batch 300 	loss 2.29 	accuracy 0.10
# epoch 0 	batch 400 	loss 2.15 	accuracy 0.10
# epoch 0 	batch 500 	loss 1.81 	accuracy 0.30
# epoch 0 	batch 600 	loss 1.94 	accuracy 0.40
# epoch 0 	batch 700 	loss 1.64 	accuracy 0.40
# epoch 0 	batch 800 	loss 2.13 	accuracy 0.10
# epoch 0 	batch 900 	loss 1.99 	accuracy 0.10
# epoch 0 	batch 1000 	loss 1.32 	accuracy 0.60
# epoch 0 	batch 1100 	loss 1.70 	accuracy 0.40
# epoch 0 	batch 1200 	loss 1.98 	accuracy 0.20
# epoch 0 	batch 1300 	loss 2.18 	accuracy 0.10
# epoch 0 	batch 1400 	loss 1.97 	accuracy 0.20
# epoch 0 	batch 1500 	loss 1.87 	accuracy 0.30
# epoch 0 	batch 1600 	loss 1.99 	accuracy 0.40
# epoch 0 	batch 1700 	loss 1.64 	accuracy 0.40
# epoch 0 	batch 1800 	loss 1.66 	accuracy 0.30
# epoch 0 	batch 1900 	loss 2.06 	accuracy 0.20
# epoch 0 	batch 2000 	loss 2.05 	accuracy 0.10
# epoch 0 	batch 2100 	loss 1.91 	accuracy 0.30
# epoch 0 	batch 2200 	loss 2.22 	accuracy 0.20
# epoch 0 	batch 2300 	loss 2.11 	accuracy 0.30
# epoch 0 	batch 2400 	loss 1.85 	accuracy 0.20
# epoch 0 	batch 2500 	loss 1.68 	accuracy 0.40
# epoch 0 	batch 2600 	loss 2.03 	accuracy 0.20
# epoch 0 	batch 2700 	loss 1.77 	accuracy 0.40
# epoch 0 	batch 2800 	loss 1.75 	accuracy 0.50
# epoch 0 	batch 2900 	loss 1.74 	accuracy 0.30
# epoch 0 	batch 3000 	loss 1.95 	accuracy 0.10
# epoch 0 	batch 3100 	loss 1.67 	accuracy 0.30
# epoch 0 	batch 3200 	loss 1.64 	accuracy 0.40
# epoch 0 	batch 3300 	loss 1.81 	accuracy 0.20
# epoch 0 	batch 3400 	loss 1.79 	accuracy 0.30
# epoch 0 	batch 3500 	loss 1.82 	accuracy 0.30
# epoch 0 	batch 3600 	loss 1.85 	accuracy 0.50
# epoch 0 	batch 3700 	loss 1.33 	accuracy 0.70
# epoch 0 	batch 3800 	loss 1.32 	accuracy 0.70
# epoch 0 	batch 3900 	loss 1.56 	accuracy 0.40
# epoch 0 	batch 4000 	loss 1.61 	accuracy 0.30
# epoch 0 	batch 4100 	loss 1.56 	accuracy 0.60
# epoch 0 	batch 4200 	loss 1.74 	accuracy 0.20
# epoch 0 	batch 4300 	loss 2.10 	accuracy 0.10
# epoch 0 	batch 4400 	loss 2.42 	accuracy 0.10
# epoch 0 	batch 4500 	loss 2.32 	accuracy 0.30
# epoch 0 	batch 4600 	loss 1.48 	accuracy 0.60
# epoch 0 	batch 4700 	loss 1.43 	accuracy 0.30
# epoch 0 	batch 4800 	loss 1.40 	accuracy 0.60
# epoch 0 	batch 4900 	loss 2.25 	accuracy 0.10
# Train Accuracy: 0.31638%
# Epoch: 0, Loss: 0.1877296444651988
# epoch 1 	batch 0 	loss 1.35 	accuracy 0.40
# epoch 1 	batch 100 	loss 1.77 	accuracy 0.20
# epoch 1 	batch 200 	loss 1.47 	accuracy 0.60
# epoch 1 	batch 300 	loss 1.76 	accuracy 0.60
# epoch 1 	batch 400 	loss 1.63 	accuracy 0.50
# epoch 1 	batch 500 	loss 1.51 	accuracy 0.50
# epoch 1 	batch 600 	loss 1.63 	accuracy 0.40
# epoch 1 	batch 700 	loss 1.42 	accuracy 0.50
# epoch 1 	batch 800 	loss 1.76 	accuracy 0.50
# epoch 1 	batch 900 	loss 2.04 	accuracy 0.10
# epoch 1 	batch 1000 	loss 2.04 	accuracy 0.30
# epoch 1 	batch 1100 	loss 1.71 	accuracy 0.30
# epoch 1 	batch 1200 	loss 1.78 	accuracy 0.30
# epoch 1 	batch 1300 	loss 1.59 	accuracy 0.30
# epoch 1 	batch 1400 	loss 1.71 	accuracy 0.50
# epoch 1 	batch 1500 	loss 1.35 	accuracy 0.50
# epoch 1 	batch 1600 	loss 1.38 	accuracy 0.40
# epoch 1 	batch 1700 	loss 1.71 	accuracy 0.30
# epoch 1 	batch 1800 	loss 1.36 	accuracy 0.40
# epoch 1 	batch 1900 	loss 1.11 	accuracy 0.60
# epoch 1 	batch 2000 	loss 1.50 	accuracy 0.60
# epoch 1 	batch 2100 	loss 1.31 	accuracy 0.50
# epoch 1 	batch 2200 	loss 1.50 	accuracy 0.60
# epoch 1 	batch 2300 	loss 1.53 	accuracy 0.50
# epoch 1 	batch 2400 	loss 1.69 	accuracy 0.50
# epoch 1 	batch 2500 	loss 2.01 	accuracy 0.40
# epoch 1 	batch 2600 	loss 1.93 	accuracy 0.30
# epoch 1 	batch 2700 	loss 1.29 	accuracy 0.40
# epoch 1 	batch 2800 	loss 1.88 	accuracy 0.40
# epoch 1 	batch 2900 	loss 1.11 	accuracy 0.60
# epoch 1 	batch 3000 	loss 1.21 	accuracy 0.60
# epoch 1 	batch 3100 	loss 1.63 	accuracy 0.30
# epoch 1 	batch 3200 	loss 1.93 	accuracy 0.30
# epoch 1 	batch 3300 	loss 1.29 	accuracy 0.70
# epoch 1 	batch 3400 	loss 1.49 	accuracy 0.50
# epoch 1 	batch 3500 	loss 1.15 	accuracy 0.50
# epoch 1 	batch 3600 	loss 1.41 	accuracy 0.70
# epoch 1 	batch 3700 	loss 1.38 	accuracy 0.40
# epoch 1 	batch 3800 	loss 2.12 	accuracy 0.40
# epoch 1 	batch 3900 	loss 2.17 	accuracy 0.30
# epoch 1 	batch 4000 	loss 1.64 	accuracy 0.40
# epoch 1 	batch 4100 	loss 1.92 	accuracy 0.30
# epoch 1 	batch 4200 	loss 1.41 	accuracy 0.40
# epoch 1 	batch 4300 	loss 1.76 	accuracy 0.20
# epoch 1 	batch 4400 	loss 1.32 	accuracy 0.40
# epoch 1 	batch 4500 	loss 1.72 	accuracy 0.40
# epoch 1 	batch 4600 	loss 1.27 	accuracy 0.50
# epoch 1 	batch 4700 	loss 1.65 	accuracy 0.20
# epoch 1 	batch 4800 	loss 1.65 	accuracy 0.40
# epoch 1 	batch 4900 	loss 1.85 	accuracy 0.30
# Train Accuracy: 0.39898%
# Epoch: 1, Loss: 0.16704860944216285
# epoch 2 	batch 0 	loss 1.14 	accuracy 0.60
# epoch 2 	batch 100 	loss 2.09 	accuracy 0.40
# epoch 2 	batch 200 	loss 2.04 	accuracy 0.50
# epoch 2 	batch 300 	loss 2.20 	accuracy 0.40
# epoch 2 	batch 400 	loss 0.89 	accuracy 0.70
# epoch 2 	batch 500 	loss 1.84 	accuracy 0.30
# epoch 2 	batch 600 	loss 1.92 	accuracy 0.40
# epoch 2 	batch 700 	loss 2.10 	accuracy 0.10
# epoch 2 	batch 800 	loss 1.71 	accuracy 0.30
# epoch 2 	batch 900 	loss 0.97 	accuracy 0.80
# epoch 2 	batch 1000 	loss 2.03 	accuracy 0.40
# epoch 2 	batch 1100 	loss 1.23 	accuracy 0.60
# epoch 2 	batch 1200 	loss 2.01 	accuracy 0.20
# epoch 2 	batch 1300 	loss 1.29 	accuracy 0.50
# epoch 2 	batch 1400 	loss 1.41 	accuracy 0.50
# epoch 2 	batch 1500 	loss 2.11 	accuracy 0.40
# epoch 2 	batch 1600 	loss 1.27 	accuracy 0.50
# epoch 2 	batch 1700 	loss 1.30 	accuracy 0.40
# epoch 2 	batch 1800 	loss 1.37 	accuracy 0.50
# epoch 2 	batch 1900 	loss 1.44 	accuracy 0.60
# epoch 2 	batch 2000 	loss 1.67 	accuracy 0.40
# epoch 2 	batch 2100 	loss 1.90 	accuracy 0.20
# epoch 2 	batch 2200 	loss 1.72 	accuracy 0.30
# epoch 2 	batch 2300 	loss 1.35 	accuracy 0.60
# epoch 2 	batch 2400 	loss 1.82 	accuracy 0.50
# epoch 2 	batch 2500 	loss 1.63 	accuracy 0.50
# epoch 2 	batch 2600 	loss 2.03 	accuracy 0.20
# epoch 2 	batch 2700 	loss 2.06 	accuracy 0.40
# epoch 2 	batch 2800 	loss 2.06 	accuracy 0.20
# epoch 2 	batch 2900 	loss 0.99 	accuracy 0.70
# epoch 2 	batch 3000 	loss 2.14 	accuracy 0.20
# epoch 2 	batch 3100 	loss 1.37 	accuracy 0.70
# epoch 2 	batch 3200 	loss 2.07 	accuracy 0.40
# epoch 2 	batch 3300 	loss 1.64 	accuracy 0.30
# epoch 2 	batch 3400 	loss 1.69 	accuracy 0.30
# epoch 2 	batch 3500 	loss 1.87 	accuracy 0.30
# epoch 2 	batch 3600 	loss 1.71 	accuracy 0.30
# epoch 2 	batch 3700 	loss 1.68 	accuracy 0.30
# epoch 2 	batch 3800 	loss 1.64 	accuracy 0.60
# epoch 2 	batch 3900 	loss 1.53 	accuracy 0.40
# epoch 2 	batch 4000 	loss 1.12 	accuracy 0.60
# epoch 2 	batch 4100 	loss 1.68 	accuracy 0.40
# epoch 2 	batch 4200 	loss 1.41 	accuracy 0.40
# epoch 2 	batch 4300 	loss 1.81 	accuracy 0.30
# epoch 2 	batch 4400 	loss 1.33 	accuracy 0.40
# epoch 2 	batch 4500 	loss 2.05 	accuracy 0.20
# epoch 2 	batch 4600 	loss 1.95 	accuracy 0.30
# epoch 2 	batch 4700 	loss 1.00 	accuracy 0.60
# epoch 2 	batch 4800 	loss 1.42 	accuracy 0.70
# epoch 2 	batch 4900 	loss 1.94 	accuracy 0.20
# Train Accuracy: 0.43018%
# Epoch: 2, Loss: 0.1584860719463291
# epoch 3 	batch 0 	loss 2.07 	accuracy 0.40
# epoch 3 	batch 100 	loss 1.38 	accuracy 0.50
# epoch 3 	batch 200 	loss 1.48 	accuracy 0.60
# epoch 3 	batch 300 	loss 1.37 	accuracy 0.50
# epoch 3 	batch 400 	loss 1.38 	accuracy 0.50
# epoch 3 	batch 500 	loss 1.30 	accuracy 0.70
# epoch 3 	batch 600 	loss 1.80 	accuracy 0.40
# epoch 3 	batch 700 	loss 1.79 	accuracy 0.30
# epoch 3 	batch 800 	loss 0.99 	accuracy 0.90
# epoch 3 	batch 900 	loss 1.58 	accuracy 0.40
# epoch 3 	batch 1000 	loss 1.58 	accuracy 0.40
# epoch 3 	batch 1100 	loss 1.27 	accuracy 0.40
# epoch 3 	batch 1200 	loss 1.70 	accuracy 0.50
# epoch 3 	batch 1300 	loss 1.49 	accuracy 0.40
# epoch 3 	batch 1400 	loss 2.05 	accuracy 0.40
# epoch 3 	batch 1500 	loss 1.46 	accuracy 0.30
# epoch 3 	batch 1600 	loss 1.31 	accuracy 0.60
# epoch 3 	batch 1700 	loss 1.27 	accuracy 0.60
# epoch 3 	batch 1800 	loss 1.21 	accuracy 0.70
# epoch 3 	batch 1900 	loss 1.97 	accuracy 0.30
# epoch 3 	batch 2000 	loss 1.65 	accuracy 0.50
# epoch 3 	batch 2100 	loss 1.35 	accuracy 0.50
# epoch 3 	batch 2200 	loss 1.42 	accuracy 0.70
# epoch 3 	batch 2300 	loss 1.36 	accuracy 0.40
# epoch 3 	batch 2400 	loss 1.50 	accuracy 0.30
# epoch 3 	batch 2500 	loss 1.60 	accuracy 0.60
# epoch 3 	batch 2600 	loss 1.39 	accuracy 0.30
# epoch 3 	batch 2700 	loss 1.42 	accuracy 0.40
# epoch 3 	batch 2800 	loss 1.85 	accuracy 0.40
# epoch 3 	batch 2900 	loss 1.98 	accuracy 0.30
# epoch 3 	batch 3000 	loss 2.20 	accuracy 0.10
# epoch 3 	batch 3100 	loss 1.08 	accuracy 0.60
# epoch 3 	batch 3200 	loss 1.68 	accuracy 0.50
# epoch 3 	batch 3300 	loss 1.49 	accuracy 0.40
# epoch 3 	batch 3400 	loss 1.95 	accuracy 0.30
# epoch 3 	batch 3500 	loss 1.31 	accuracy 0.50
# epoch 3 	batch 3600 	loss 1.46 	accuracy 0.50
# epoch 3 	batch 3700 	loss 1.62 	accuracy 0.60
# epoch 3 	batch 3800 	loss 1.66 	accuracy 0.50
# epoch 3 	batch 3900 	loss 1.20 	accuracy 0.50
# epoch 3 	batch 4000 	loss 1.71 	accuracy 0.20
# epoch 3 	batch 4100 	loss 1.39 	accuracy 0.50
# epoch 3 	batch 4200 	loss 2.00 	accuracy 0.20
# epoch 3 	batch 4300 	loss 1.42 	accuracy 0.50
# epoch 3 	batch 4400 	loss 1.17 	accuracy 0.60
# epoch 3 	batch 4500 	loss 1.58 	accuracy 0.40
# epoch 3 	batch 4600 	loss 2.06 	accuracy 0.30
# epoch 3 	batch 4700 	loss 1.62 	accuracy 0.40
# epoch 3 	batch 4800 	loss 1.59 	accuracy 0.60
# epoch 3 	batch 4900 	loss 1.84 	accuracy 0.40
# Train Accuracy: 0.45542%
# Epoch: 3, Loss: 0.15239072953188323
# epoch 4 	batch 0 	loss 1.91 	accuracy 0.50
# epoch 4 	batch 100 	loss 1.17 	accuracy 0.60
# epoch 4 	batch 200 	loss 0.83 	accuracy 0.90
# epoch 4 	batch 300 	loss 1.06 	accuracy 0.60
# epoch 4 	batch 400 	loss 1.48 	accuracy 0.50
# epoch 4 	batch 500 	loss 1.60 	accuracy 0.50
# epoch 4 	batch 600 	loss 1.02 	accuracy 0.70
# epoch 4 	batch 700 	loss 1.87 	accuracy 0.40
# epoch 4 	batch 800 	loss 0.82 	accuracy 0.70
# epoch 4 	batch 900 	loss 1.61 	accuracy 0.60
# epoch 4 	batch 1000 	loss 1.10 	accuracy 0.70
# epoch 4 	batch 1100 	loss 1.30 	accuracy 0.50
# epoch 4 	batch 1200 	loss 1.44 	accuracy 0.60
# epoch 4 	batch 1300 	loss 1.46 	accuracy 0.40
# epoch 4 	batch 1400 	loss 0.93 	accuracy 0.80
# epoch 4 	batch 1500 	loss 1.73 	accuracy 0.40
# epoch 4 	batch 1600 	loss 1.26 	accuracy 0.50
# epoch 4 	batch 1700 	loss 1.56 	accuracy 0.30
# epoch 4 	batch 1800 	loss 1.95 	accuracy 0.20
# epoch 4 	batch 1900 	loss 1.45 	accuracy 0.30
# epoch 4 	batch 2000 	loss 1.33 	accuracy 0.50
# epoch 4 	batch 2100 	loss 1.92 	accuracy 0.40
# epoch 4 	batch 2200 	loss 1.62 	accuracy 0.40
# epoch 4 	batch 2300 	loss 1.41 	accuracy 0.40
# epoch 4 	batch 2400 	loss 1.35 	accuracy 0.70
# epoch 4 	batch 2500 	loss 1.22 	accuracy 0.60
# epoch 4 	batch 2600 	loss 1.52 	accuracy 0.40
# epoch 4 	batch 2700 	loss 1.83 	accuracy 0.40
# epoch 4 	batch 2800 	loss 1.27 	accuracy 0.50
# epoch 4 	batch 2900 	loss 1.70 	accuracy 0.50
# epoch 4 	batch 3000 	loss 1.55 	accuracy 0.40
# epoch 4 	batch 3100 	loss 1.87 	accuracy 0.20
# epoch 4 	batch 3200 	loss 1.55 	accuracy 0.60
# epoch 4 	batch 3300 	loss 1.32 	accuracy 0.60
# epoch 4 	batch 3400 	loss 2.05 	accuracy 0.40
# epoch 4 	batch 3500 	loss 1.89 	accuracy 0.30
# epoch 4 	batch 3600 	loss 1.07 	accuracy 0.60
# epoch 4 	batch 3700 	loss 1.27 	accuracy 0.60
# epoch 4 	batch 3800 	loss 1.51 	accuracy 0.50
# epoch 4 	batch 3900 	loss 1.77 	accuracy 0.30
# epoch 4 	batch 4000 	loss 1.29 	accuracy 0.40
# epoch 4 	batch 4100 	loss 1.32 	accuracy 0.50
# epoch 4 	batch 4200 	loss 0.86 	accuracy 0.70
# epoch 4 	batch 4300 	loss 1.01 	accuracy 0.60
# epoch 4 	batch 4400 	loss 1.51 	accuracy 0.40
# epoch 4 	batch 4500 	loss 0.99 	accuracy 0.50
# epoch 4 	batch 4600 	loss 1.49 	accuracy 0.40
# epoch 4 	batch 4700 	loss 1.73 	accuracy 0.30
# epoch 4 	batch 4800 	loss 1.26 	accuracy 0.40
# epoch 4 	batch 4900 	loss 1.47 	accuracy 0.30
# Train Accuracy: 0.47292%
# Epoch: 4, Loss: 0.1473519032854653
# epoch 5 	batch 0 	loss 1.73 	accuracy 0.30
# epoch 5 	batch 100 	loss 1.19 	accuracy 0.70
# epoch 5 	batch 200 	loss 2.02 	accuracy 0.30
# epoch 5 	batch 300 	loss 1.46 	accuracy 0.60
# epoch 5 	batch 400 	loss 1.13 	accuracy 0.60
# epoch 5 	batch 500 	loss 1.33 	accuracy 0.50
# epoch 5 	batch 600 	loss 1.90 	accuracy 0.60
# epoch 5 	batch 700 	loss 1.21 	accuracy 0.50
# epoch 5 	batch 800 	loss 1.33 	accuracy 0.60
# epoch 5 	batch 900 	loss 1.17 	accuracy 0.50
# epoch 5 	batch 1000 	loss 1.18 	accuracy 0.60
# epoch 5 	batch 1100 	loss 1.53 	accuracy 0.40
# epoch 5 	batch 1200 	loss 1.57 	accuracy 0.20
# epoch 5 	batch 1300 	loss 1.53 	accuracy 0.50
# epoch 5 	batch 1400 	loss 1.60 	accuracy 0.40
# epoch 5 	batch 1500 	loss 1.25 	accuracy 0.60
# epoch 5 	batch 1600 	loss 1.78 	accuracy 0.40
# epoch 5 	batch 1700 	loss 1.08 	accuracy 0.60
# epoch 5 	batch 1800 	loss 1.71 	accuracy 0.50
# epoch 5 	batch 1900 	loss 1.19 	accuracy 0.80
# epoch 5 	batch 2000 	loss 1.69 	accuracy 0.40
# epoch 5 	batch 2100 	loss 1.58 	accuracy 0.50
# epoch 5 	batch 2200 	loss 1.18 	accuracy 0.70
# epoch 5 	batch 2300 	loss 1.16 	accuracy 0.70
# epoch 5 	batch 2400 	loss 1.46 	accuracy 0.30
# epoch 5 	batch 2500 	loss 1.53 	accuracy 0.40
# epoch 5 	batch 2600 	loss 1.12 	accuracy 0.70
# epoch 5 	batch 2700 	loss 1.98 	accuracy 0.20
# epoch 5 	batch 2800 	loss 1.12 	accuracy 0.50
# epoch 5 	batch 2900 	loss 1.77 	accuracy 0.30
# epoch 5 	batch 3000 	loss 1.78 	accuracy 0.40
# epoch 5 	batch 3100 	loss 1.06 	accuracy 0.60
# epoch 5 	batch 3200 	loss 1.43 	accuracy 0.50
# epoch 5 	batch 3300 	loss 1.38 	accuracy 0.60
# epoch 5 	batch 3400 	loss 1.14 	accuracy 0.50
# epoch 5 	batch 3500 	loss 2.10 	accuracy 0.20
# epoch 5 	batch 3600 	loss 1.42 	accuracy 0.40
# epoch 5 	batch 3700 	loss 1.10 	accuracy 0.40
# epoch 5 	batch 3800 	loss 1.36 	accuracy 0.50
# epoch 5 	batch 3900 	loss 1.26 	accuracy 0.60
# epoch 5 	batch 4000 	loss 1.31 	accuracy 0.40
# epoch 5 	batch 4100 	loss 1.02 	accuracy 0.80
# epoch 5 	batch 4200 	loss 1.28 	accuracy 0.60
# epoch 5 	batch 4300 	loss 1.68 	accuracy 0.60
# epoch 5 	batch 4400 	loss 1.21 	accuracy 0.60
# epoch 5 	batch 4500 	loss 1.38 	accuracy 0.40
# epoch 5 	batch 4600 	loss 1.13 	accuracy 0.50
# epoch 5 	batch 4700 	loss 1.39 	accuracy 0.50
# epoch 5 	batch 4800 	loss 1.35 	accuracy 0.50
# epoch 5 	batch 4900 	loss 1.45 	accuracy 0.50
# Train Accuracy: 0.4896%
# Epoch: 5, Loss: 0.14293696371944098
# epoch 6 	batch 0 	loss 1.73 	accuracy 0.10
# epoch 6 	batch 100 	loss 1.92 	accuracy 0.40
# epoch 6 	batch 200 	loss 1.33 	accuracy 0.40
# epoch 6 	batch 300 	loss 2.34 	accuracy 0.30
# epoch 6 	batch 400 	loss 1.14 	accuracy 0.50
# epoch 6 	batch 500 	loss 1.36 	accuracy 0.50
# epoch 6 	batch 600 	loss 1.66 	accuracy 0.30
# epoch 6 	batch 700 	loss 0.51 	accuracy 0.90
# epoch 6 	batch 800 	loss 1.47 	accuracy 0.30
# epoch 6 	batch 900 	loss 1.12 	accuracy 0.70
# epoch 6 	batch 1000 	loss 1.21 	accuracy 0.70
# epoch 6 	batch 1100 	loss 1.45 	accuracy 0.30
# epoch 6 	batch 1200 	loss 1.33 	accuracy 0.60
# epoch 6 	batch 1300 	loss 1.05 	accuracy 0.60
# epoch 6 	batch 1400 	loss 1.40 	accuracy 0.60
# epoch 6 	batch 1500 	loss 1.04 	accuracy 0.60
# epoch 6 	batch 1600 	loss 1.57 	accuracy 0.50
# epoch 6 	batch 1700 	loss 1.24 	accuracy 0.60
# epoch 6 	batch 1800 	loss 1.81 	accuracy 0.40
# epoch 6 	batch 1900 	loss 1.35 	accuracy 0.40
# epoch 6 	batch 2000 	loss 1.57 	accuracy 0.50
# epoch 6 	batch 2100 	loss 1.14 	accuracy 0.60
# epoch 6 	batch 2200 	loss 1.35 	accuracy 0.70
# epoch 6 	batch 2300 	loss 1.99 	accuracy 0.30
# epoch 6 	batch 2400 	loss 0.73 	accuracy 0.80
# epoch 6 	batch 2500 	loss 1.34 	accuracy 0.60
# epoch 6 	batch 2600 	loss 0.76 	accuracy 0.70
# epoch 6 	batch 2700 	loss 1.51 	accuracy 0.30
# epoch 6 	batch 2800 	loss 1.56 	accuracy 0.40
# epoch 6 	batch 2900 	loss 0.83 	accuracy 0.90
# epoch 6 	batch 3000 	loss 1.25 	accuracy 0.50
# epoch 6 	batch 3100 	loss 1.28 	accuracy 0.60
# epoch 6 	batch 3200 	loss 1.81 	accuracy 0.20
# epoch 6 	batch 3300 	loss 1.23 	accuracy 0.50
# epoch 6 	batch 3400 	loss 1.01 	accuracy 0.80
# epoch 6 	batch 3500 	loss 1.39 	accuracy 0.50
# epoch 6 	batch 3600 	loss 1.78 	accuracy 0.50
# epoch 6 	batch 3700 	loss 1.49 	accuracy 0.40
# epoch 6 	batch 3800 	loss 1.40 	accuracy 0.40
# epoch 6 	batch 3900 	loss 1.46 	accuracy 0.60
# epoch 6 	batch 4000 	loss 1.01 	accuracy 0.50
# epoch 6 	batch 4100 	loss 1.08 	accuracy 0.50
# epoch 6 	batch 4200 	loss 0.95 	accuracy 0.60
# epoch 6 	batch 4300 	loss 1.38 	accuracy 0.40
# epoch 6 	batch 4400 	loss 0.70 	accuracy 0.80
# epoch 6 	batch 4500 	loss 1.07 	accuracy 0.60
# epoch 6 	batch 4600 	loss 1.82 	accuracy 0.50
# epoch 6 	batch 4700 	loss 0.92 	accuracy 0.80
# epoch 6 	batch 4800 	loss 1.08 	accuracy 0.60
# epoch 6 	batch 4900 	loss 1.52 	accuracy 0.40
# Train Accuracy: 0.50466%
# Epoch: 6, Loss: 0.13890132476827086
# epoch 7 	batch 0 	loss 1.82 	accuracy 0.20
# epoch 7 	batch 100 	loss 1.45 	accuracy 0.50
# epoch 7 	batch 200 	loss 1.15 	accuracy 0.70
# epoch 7 	batch 300 	loss 1.24 	accuracy 0.50
# epoch 7 	batch 400 	loss 1.23 	accuracy 0.40
# epoch 7 	batch 500 	loss 1.51 	accuracy 0.40
# epoch 7 	batch 600 	loss 1.67 	accuracy 0.30
# epoch 7 	batch 700 	loss 1.01 	accuracy 0.60
# epoch 7 	batch 800 	loss 1.69 	accuracy 0.40
# epoch 7 	batch 900 	loss 1.37 	accuracy 0.50
# epoch 7 	batch 1000 	loss 0.94 	accuracy 0.60
# epoch 7 	batch 1100 	loss 1.13 	accuracy 0.60
# epoch 7 	batch 1200 	loss 0.78 	accuracy 0.80
# epoch 7 	batch 1300 	loss 0.96 	accuracy 0.80
# epoch 7 	batch 1400 	loss 1.05 	accuracy 0.70
# epoch 7 	batch 1500 	loss 1.81 	accuracy 0.40
# epoch 7 	batch 1600 	loss 1.10 	accuracy 0.70
# epoch 7 	batch 1700 	loss 1.82 	accuracy 0.30
# epoch 7 	batch 1800 	loss 1.47 	accuracy 0.30
# epoch 7 	batch 1900 	loss 1.37 	accuracy 0.50
# epoch 7 	batch 2000 	loss 1.00 	accuracy 0.70
# epoch 7 	batch 2100 	loss 1.29 	accuracy 0.40
# epoch 7 	batch 2200 	loss 1.05 	accuracy 0.60
# epoch 7 	batch 2300 	loss 0.98 	accuracy 0.70
# epoch 7 	batch 2400 	loss 1.52 	accuracy 0.40
# epoch 7 	batch 2500 	loss 1.51 	accuracy 0.40
# epoch 7 	batch 2600 	loss 2.29 	accuracy 0.20
# epoch 7 	batch 2700 	loss 1.87 	accuracy 0.30
# epoch 7 	batch 2800 	loss 1.04 	accuracy 0.70
# epoch 7 	batch 2900 	loss 0.92 	accuracy 0.60
# epoch 7 	batch 3000 	loss 1.37 	accuracy 0.50
# epoch 7 	batch 3100 	loss 1.39 	accuracy 0.50
# epoch 7 	batch 3200 	loss 0.88 	accuracy 0.80
# epoch 7 	batch 3300 	loss 0.88 	accuracy 0.70
# epoch 7 	batch 3400 	loss 0.97 	accuracy 0.70
# epoch 7 	batch 3500 	loss 1.50 	accuracy 0.40
# epoch 7 	batch 3600 	loss 1.36 	accuracy 0.50
# epoch 7 	batch 3700 	loss 1.54 	accuracy 0.40
# epoch 7 	batch 3800 	loss 0.60 	accuracy 0.90
# epoch 7 	batch 3900 	loss 1.72 	accuracy 0.60
# epoch 7 	batch 4000 	loss 1.35 	accuracy 0.50
# epoch 7 	batch 4100 	loss 1.49 	accuracy 0.50
# epoch 7 	batch 4200 	loss 1.35 	accuracy 0.50
# epoch 7 	batch 4300 	loss 1.25 	accuracy 0.60
# epoch 7 	batch 4400 	loss 1.14 	accuracy 0.60
# epoch 7 	batch 4500 	loss 1.40 	accuracy 0.50
# epoch 7 	batch 4600 	loss 1.34 	accuracy 0.40
# epoch 7 	batch 4700 	loss 1.01 	accuracy 0.50
# epoch 7 	batch 4800 	loss 0.98 	accuracy 0.60
# epoch 7 	batch 4900 	loss 1.03 	accuracy 0.60
# Train Accuracy: 0.51794%
# Epoch: 7, Loss: 0.13499369849675072
# epoch 8 	batch 0 	loss 1.11 	accuracy 0.60
# epoch 8 	batch 100 	loss 1.65 	accuracy 0.50
# epoch 8 	batch 200 	loss 1.41 	accuracy 0.50
# epoch 8 	batch 300 	loss 1.38 	accuracy 0.30
# epoch 8 	batch 400 	loss 1.16 	accuracy 0.60
# epoch 8 	batch 500 	loss 0.66 	accuracy 1.00
# epoch 8 	batch 600 	loss 1.18 	accuracy 0.50
# epoch 8 	batch 700 	loss 1.17 	accuracy 0.50
# epoch 8 	batch 800 	loss 1.60 	accuracy 0.30
# epoch 8 	batch 900 	loss 1.06 	accuracy 0.60
# epoch 8 	batch 1000 	loss 1.21 	accuracy 0.50
# epoch 8 	batch 1100 	loss 0.97 	accuracy 0.50
# epoch 8 	batch 1200 	loss 0.86 	accuracy 0.90
# epoch 8 	batch 1300 	loss 0.99 	accuracy 0.50
# epoch 8 	batch 1400 	loss 1.47 	accuracy 0.50
# epoch 8 	batch 1500 	loss 1.46 	accuracy 0.60
# epoch 8 	batch 1600 	loss 1.48 	accuracy 0.50
# epoch 8 	batch 1700 	loss 1.28 	accuracy 0.40
# epoch 8 	batch 1800 	loss 1.49 	accuracy 0.50
# epoch 8 	batch 1900 	loss 1.10 	accuracy 0.60
# epoch 8 	batch 2000 	loss 1.15 	accuracy 0.40
# epoch 8 	batch 2100 	loss 0.65 	accuracy 0.90
# epoch 8 	batch 2200 	loss 1.53 	accuracy 0.20
# epoch 8 	batch 2300 	loss 0.95 	accuracy 0.70
# epoch 8 	batch 2400 	loss 1.74 	accuracy 0.40
# epoch 8 	batch 2500 	loss 1.64 	accuracy 0.50
# epoch 8 	batch 2600 	loss 2.03 	accuracy 0.30
# epoch 8 	batch 2700 	loss 0.75 	accuracy 0.70
# epoch 8 	batch 2800 	loss 1.34 	accuracy 0.40
# epoch 8 	batch 2900 	loss 1.36 	accuracy 0.60
# epoch 8 	batch 3000 	loss 1.36 	accuracy 0.60
# epoch 8 	batch 3100 	loss 1.51 	accuracy 0.40
# epoch 8 	batch 3200 	loss 1.09 	accuracy 0.50
# epoch 8 	batch 3300 	loss 0.75 	accuracy 0.80
# epoch 8 	batch 3400 	loss 1.14 	accuracy 0.70
# epoch 8 	batch 3500 	loss 1.11 	accuracy 0.40
# epoch 8 	batch 3600 	loss 1.54 	accuracy 0.40
# epoch 8 	batch 3700 	loss 0.97 	accuracy 0.70
# epoch 8 	batch 3800 	loss 0.71 	accuracy 0.80
# epoch 8 	batch 3900 	loss 1.06 	accuracy 0.60
# epoch 8 	batch 4000 	loss 1.21 	accuracy 0.60
# epoch 8 	batch 4100 	loss 0.86 	accuracy 0.70
# epoch 8 	batch 4200 	loss 1.16 	accuracy 0.60
# epoch 8 	batch 4300 	loss 1.26 	accuracy 0.40
# epoch 8 	batch 4400 	loss 1.95 	accuracy 0.20
# epoch 8 	batch 4500 	loss 0.99 	accuracy 0.60
# epoch 8 	batch 4600 	loss 1.71 	accuracy 0.30
# epoch 8 	batch 4700 	loss 1.14 	accuracy 0.60
# epoch 8 	batch 4800 	loss 1.01 	accuracy 0.70
# epoch 8 	batch 4900 	loss 1.46 	accuracy 0.30
# Train Accuracy: 0.52858%
# Epoch: 8, Loss: 0.13158967215072095
# epoch 9 	batch 0 	loss 1.49 	accuracy 0.40
# epoch 9 	batch 100 	loss 0.71 	accuracy 0.70
# epoch 9 	batch 200 	loss 1.36 	accuracy 0.60
# epoch 9 	batch 300 	loss 1.19 	accuracy 0.60
# epoch 9 	batch 400 	loss 1.79 	accuracy 0.30
# epoch 9 	batch 500 	loss 1.52 	accuracy 0.50
# epoch 9 	batch 600 	loss 1.29 	accuracy 0.40
# epoch 9 	batch 700 	loss 0.93 	accuracy 0.70
# epoch 9 	batch 800 	loss 0.90 	accuracy 0.70
# epoch 9 	batch 900 	loss 1.54 	accuracy 0.30
# epoch 9 	batch 1000 	loss 0.66 	accuracy 0.90
# epoch 9 	batch 1100 	loss 2.10 	accuracy 0.30
# epoch 9 	batch 1200 	loss 1.20 	accuracy 0.60
# epoch 9 	batch 1300 	loss 1.49 	accuracy 0.30
# epoch 9 	batch 1400 	loss 1.27 	accuracy 0.50
# epoch 9 	batch 1500 	loss 1.35 	accuracy 0.40
# epoch 9 	batch 1600 	loss 0.94 	accuracy 0.70
# epoch 9 	batch 1700 	loss 0.89 	accuracy 0.70
# epoch 9 	batch 1800 	loss 1.04 	accuracy 0.70
# epoch 9 	batch 1900 	loss 1.60 	accuracy 0.50
# epoch 9 	batch 2000 	loss 1.13 	accuracy 0.70
# epoch 9 	batch 2100 	loss 1.11 	accuracy 0.60
# epoch 9 	batch 2200 	loss 1.33 	accuracy 0.40
# epoch 9 	batch 2300 	loss 1.39 	accuracy 0.60
# epoch 9 	batch 2400 	loss 1.68 	accuracy 0.30
# epoch 9 	batch 2500 	loss 1.42 	accuracy 0.40
# epoch 9 	batch 2600 	loss 1.19 	accuracy 0.50
# epoch 9 	batch 2700 	loss 1.02 	accuracy 0.50
# epoch 9 	batch 2800 	loss 1.24 	accuracy 0.30
# epoch 9 	batch 2900 	loss 0.87 	accuracy 0.70
# epoch 9 	batch 3000 	loss 1.51 	accuracy 0.50
# epoch 9 	batch 3100 	loss 1.03 	accuracy 0.70
# epoch 9 	batch 3200 	loss 1.17 	accuracy 0.80
# epoch 9 	batch 3300 	loss 1.18 	accuracy 0.40
# epoch 9 	batch 3400 	loss 1.77 	accuracy 0.40
# epoch 9 	batch 3500 	loss 1.42 	accuracy 0.50
# epoch 9 	batch 3600 	loss 1.95 	accuracy 0.20
# epoch 9 	batch 3700 	loss 1.65 	accuracy 0.50
# epoch 9 	batch 3800 	loss 0.72 	accuracy 0.70
# epoch 9 	batch 3900 	loss 1.12 	accuracy 0.70
# epoch 9 	batch 4000 	loss 1.03 	accuracy 0.60
# epoch 9 	batch 4100 	loss 1.34 	accuracy 0.50
# epoch 9 	batch 4200 	loss 1.55 	accuracy 0.50
# epoch 9 	batch 4300 	loss 1.65 	accuracy 0.50
# epoch 9 	batch 4400 	loss 1.20 	accuracy 0.60
# epoch 9 	batch 4500 	loss 1.47 	accuracy 0.60
# epoch 9 	batch 4600 	loss 1.33 	accuracy 0.50
# epoch 9 	batch 4700 	loss 1.83 	accuracy 0.30
# epoch 9 	batch 4800 	loss 0.83 	accuracy 0.70
# epoch 9 	batch 4900 	loss 1.06 	accuracy 0.50
# Train Accuracy: 0.5398%
# Epoch: 9, Loss: 0.12846332594724671

# %%
paddle.save(model.state_dict(), "train2.model")

# %%
m = MyDNN()
m.set_state_dict(paddle.load("train2.model"))
m.eval()
eval_loader = paddle.io.DataLoader(
    Reader("../data/cifar-10-batches-py/test_batch"), batch_size=1000, shuffle=True
)

accs = []
for i, (x, y) in enumerate(eval_loader):
    y_pred = m(x)
    mask = np.array(y_pred, copy=False).argmax(1) == y
    acc = mask.sum().numpy() / batch
    print(i, acc)
    accs.append(acc)
print(np.mean(accs))
# Out:
# 0 50.3
# 1 51.3
# 2 50.7
# 3 49.2
# 4 50.2
# 5 50.9
# 6 49.9
# 7 52.3
# 8 49.9
# 9 50.3
# 50.49999999999999

# %%
a=unpickle("../data/cifar-10-batches-py/test_batch")

# %%
for t in range(100):
    (x,y)=getitem(a,t)
    # plt.imshow(x)
    # plt.axis("off")
    # plt.show()
    y_pred=np.array(m(paddle.Tensor(a[b'data'][t]/255))).argmax()
    print(y==y_pred,"\t",label_names[y],"\tpred:",label_names[y_pred])
# Out:
# True 	 b'cat' 	pred: b'cat'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'ship' 	pred: b'ship'
# False 	 b'airplane' 	pred: b'ship'
# False 	 b'frog' 	pred: b'deer'
# True 	 b'frog' 	pred: b'frog'
# False 	 b'automobile' 	pred: b'dog'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'cat' 	pred: b'cat'
# True 	 b'automobile' 	pred: b'automobile'
# True 	 b'airplane' 	pred: b'airplane'
# True 	 b'truck' 	pred: b'truck'
# True 	 b'dog' 	pred: b'dog'
# True 	 b'horse' 	pred: b'horse'
# True 	 b'truck' 	pred: b'truck'
# False 	 b'ship' 	pred: b'dog'
# True 	 b'dog' 	pred: b'dog'
# False 	 b'horse' 	pred: b'truck'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'frog' 	pred: b'frog'
# False 	 b'horse' 	pred: b'automobile'
# False 	 b'airplane' 	pred: b'bird'
# False 	 b'deer' 	pred: b'bird'
# True 	 b'truck' 	pred: b'truck'
# False 	 b'dog' 	pred: b'deer'
# False 	 b'bird' 	pred: b'frog'
# True 	 b'deer' 	pred: b'deer'
# False 	 b'airplane' 	pred: b'horse'
# True 	 b'truck' 	pred: b'truck'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'dog' 	pred: b'dog'
# True 	 b'deer' 	pred: b'deer'
# True 	 b'dog' 	pred: b'dog'
# True 	 b'truck' 	pred: b'truck'
# False 	 b'bird' 	pred: b'automobile'
# False 	 b'deer' 	pred: b'frog'
# False 	 b'automobile' 	pred: b'truck'
# True 	 b'truck' 	pred: b'truck'
# False 	 b'dog' 	pred: b'ship'
# True 	 b'deer' 	pred: b'deer'
# True 	 b'frog' 	pred: b'frog'
# False 	 b'dog' 	pred: b'horse'
# False 	 b'frog' 	pred: b'deer'
# False 	 b'airplane' 	pred: b'deer'
# True 	 b'truck' 	pred: b'truck'
# True 	 b'cat' 	pred: b'cat'
# False 	 b'truck' 	pred: b'ship'
# True 	 b'horse' 	pred: b'horse'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'truck' 	pred: b'truck'
# False 	 b'ship' 	pred: b'deer'
# False 	 b'airplane' 	pred: b'frog'
# True 	 b'cat' 	pred: b'cat'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'ship' 	pred: b'ship'
# False 	 b'horse' 	pred: b'dog'
# False 	 b'horse' 	pred: b'frog'
# False 	 b'deer' 	pred: b'cat'
# False 	 b'frog' 	pred: b'deer'
# True 	 b'horse' 	pred: b'horse'
# True 	 b'cat' 	pred: b'cat'
# True 	 b'frog' 	pred: b'frog'
# False 	 b'cat' 	pred: b'truck'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'bird' 	pred: b'bird'
# False 	 b'automobile' 	pred: b'ship'
# True 	 b'bird' 	pred: b'bird'
# False 	 b'cat' 	pred: b'dog'
# False 	 b'horse' 	pred: b'truck'
# False 	 b'bird' 	pred: b'deer'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'airplane' 	pred: b'airplane'
# False 	 b'bird' 	pred: b'frog'
# True 	 b'truck' 	pred: b'truck'
# True 	 b'cat' 	pred: b'cat'
# True 	 b'cat' 	pred: b'cat'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'automobile' 	pred: b'automobile'
# True 	 b'automobile' 	pred: b'automobile'
# False 	 b'horse' 	pred: b'dog'
# False 	 b'bird' 	pred: b'horse'
# False 	 b'dog' 	pred: b'horse'
# True 	 b'bird' 	pred: b'bird'
# False 	 b'horse' 	pred: b'airplane'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'truck' 	pred: b'truck'
# True 	 b'airplane' 	pred: b'airplane'
# False 	 b'cat' 	pred: b'dog'
# True 	 b'ship' 	pred: b'ship'
# True 	 b'frog' 	pred: b'frog'
# True 	 b'deer' 	pred: b'deer'
# False 	 b'frog' 	pred: b'dog'
# False 	 b'frog' 	pred: b'deer'
# False 	 b'airplane' 	pred: b'bird'
# False 	 b'airplane' 	pred: b'horse'
# True 	 b'horse' 	pred: b'horse'

# %%
m(paddle.Tensor(a[b'data'][1]/255))
# Out:
# Tensor(shape=[10], dtype=float64, place=Place(cpu), stop_gradient=False,
#        [ 0.17504770,  1.57317614, -1.13753433, -1.71715024, -1.87830133,
#         -2.39520167, -2.53039684, -1.82821071,  2.52066157,  2.37053610])
