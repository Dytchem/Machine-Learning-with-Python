# %%
import os
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
import paddle

paddle.set_device("cpu")
paddle.set_default_dtype("float64")

# %%
def unpickle(file):
    import pickle

    with open(file, "rb") as fo:
        dict = pickle.load(fo, encoding="bytes")
    return dict


def getitem(dict, index):
    label = a[b"labels"][index]
    image_data = a[b"data"][index]
    red_channel = image_data[:1024].reshape((32, 32))
    green_channel = image_data[1024:2048].reshape((32, 32))
    blue_channel = image_data[2048:].reshape((32, 32))
    rgb_image = np.dstack((red_channel, green_channel, blue_channel))
    return rgb_image, label


label_names = unpickle("../data/cifar-10-batches-py/batches.meta")[b"label_names"]

# %%
class Reader(paddle.io.Dataset):
    def __init__(self, *path):
        super().__init__()
        data = unpickle(path[0])
        self.x = data[b"data"] / 255
        self.y = data[b"labels"]
        for i in range(1, len(path)):
            data = unpickle(path[i])
            self.x = np.concatenate((self.x, data[b"data"] / 255))
            self.y = np.concatenate((self.y, data[b"labels"]))

    def __getitem__(self, index):
        return self.x[index].reshape((3, 32, 32)), self.y[index]

    def __len__(self):
        return len(self.y)

# %%
class MyCNN(paddle.nn.Layer):
    def __init__(self):
        super(MyCNN, self).__init__()
        self.conv0 = paddle.nn.Conv2D(3, 64, 3, 1, 0)
        self.pool0 = paddle.nn.MaxPool2D(2, 2)
        self.conv1 = paddle.nn.Conv2D(64, 128, 4, 1, 0)
        self.pool1 = paddle.nn.MaxPool2D(2, 2)
        self.conv2 = paddle.nn.Conv2D(128, 128, 5, 1, 0)
        self.pool2 = paddle.nn.MaxPool2D(2, 2)
        self.fc = paddle.nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv0(x)
        x = self.pool0(x)
        x = self.conv1(x)
        x = self.pool1(x)
        x = self.conv2(x)
        x = self.pool2(x)
        x = x.flatten(1)
        # print(x.shape)
        x = self.fc(x)
        return x

# %%
model = MyCNN()
cross_entropy = paddle.nn.CrossEntropyLoss()
opt = paddle.optimizer.SGD(0.01, model.parameters(), weight_decay=0.01)

model.train()
epoch = 10
batch = 10
train_loader = paddle.io.DataLoader(
    Reader(
        "../data/cifar-10-batches-py/data_batch_1",
        "../data/cifar-10-batches-py/data_batch_2",
        "../data/cifar-10-batches-py/data_batch_3",
        "../data/cifar-10-batches-py/data_batch_4",
        "../data/cifar-10-batches-py/data_batch_5",
    ),
    batch_size=batch,
    shuffle=True,
)

for e in range(epoch):
    full_loss = 0
    n_loss = 0
    n_eval = 0
    correct = 0
    for i, (x, y) in enumerate(train_loader):
        if i % 100 == 0:
            print("epoch", e, "\tbatch", i, end=" ")

        y_pred = model(x)
        loss = cross_entropy(y_pred, y)

        loss.backward()
        opt.step()

        full_loss += loss.numpy()
        n_loss += batch
        opt.clear_grad()

        mask = np.array(y_pred, copy=False).argmax(1) == y
        co = mask.sum().numpy()
        correct += co

        if i % 100 == 0:
            print(f"\tloss {loss.numpy():.2f} \taccuracy {co/batch:.2f}")
    print(f"Train Accuracy: {correct*100/n_loss}%")
    print(f"Epoch: {e}, Loss: {full_loss / n_loss}")
# Out:
# epoch 0 	batch 0 	loss 3.44 	accuracy 0.10
# epoch 0 	batch 100 	loss 1.77 	accuracy 0.50
# epoch 0 	batch 200 	loss 2.20 	accuracy 0.30
# epoch 0 	batch 300 	loss 1.45 	accuracy 0.40
# epoch 0 	batch 400 	loss 1.32 	accuracy 0.50
# epoch 0 	batch 500 	loss 1.35 	accuracy 0.60
# epoch 0 	batch 600 	loss 1.51 	accuracy 0.50
# epoch 0 	batch 700 	loss 1.65 	accuracy 0.30
# epoch 0 	batch 800 	loss 1.43 	accuracy 0.50
# epoch 0 	batch 900 	loss 1.47 	accuracy 0.50
# epoch 0 	batch 1000 	loss 1.72 	accuracy 0.50
# epoch 0 	batch 1100 	loss 1.67 	accuracy 0.40
# epoch 0 	batch 1200 	loss 1.53 	accuracy 0.30
# epoch 0 	batch 1300 	loss 1.43 	accuracy 0.50
# epoch 0 	batch 1400 	loss 1.34 	accuracy 0.60
# epoch 0 	batch 1500 	loss 1.78 	accuracy 0.40
# epoch 0 	batch 1600 	loss 1.72 	accuracy 0.40
# epoch 0 	batch 1700 	loss 1.67 	accuracy 0.50
# epoch 0 	batch 1800 	loss 1.02 	accuracy 0.60
# epoch 0 	batch 1900 	loss 1.55 	accuracy 0.50
# epoch 0 	batch 2000 	loss 1.60 	accuracy 0.30
# epoch 0 	batch 2100 	loss 1.70 	accuracy 0.30
# epoch 0 	batch 2200 	loss 1.19 	accuracy 0.70
# epoch 0 	batch 2300 	loss 0.88 	accuracy 0.80
# epoch 0 	batch 2400 	loss 1.41 	accuracy 0.40
# epoch 0 	batch 2500 	loss 1.54 	accuracy 0.40
# epoch 0 	batch 2600 	loss 1.44 	accuracy 0.80
# epoch 0 	batch 2700 	loss 0.88 	accuracy 0.60
# epoch 0 	batch 2800 	loss 1.89 	accuracy 0.20
# epoch 0 	batch 2900 	loss 1.58 	accuracy 0.30
# epoch 0 	batch 3000 	loss 1.58 	accuracy 0.40
# epoch 0 	batch 3100 	loss 0.93 	accuracy 0.70
# epoch 0 	batch 3200 	loss 1.53 	accuracy 0.50
# epoch 0 	batch 3300 	loss 1.26 	accuracy 0.40
# epoch 0 	batch 3400 	loss 1.31 	accuracy 0.50
# epoch 0 	batch 3500 	loss 1.50 	accuracy 0.20
# epoch 0 	batch 3600 	loss 1.42 	accuracy 0.40
# epoch 0 	batch 3700 	loss 1.62 	accuracy 0.20
# epoch 0 	batch 3800 	loss 1.11 	accuracy 0.60
# epoch 0 	batch 3900 	loss 0.95 	accuracy 0.70
# epoch 0 	batch 4000 	loss 1.39 	accuracy 0.40
# epoch 0 	batch 4100 	loss 1.02 	accuracy 0.50
# epoch 0 	batch 4200 	loss 2.01 	accuracy 0.20
# epoch 0 	batch 4300 	loss 1.09 	accuracy 0.80
# epoch 0 	batch 4400 	loss 1.14 	accuracy 0.70
# epoch 0 	batch 4500 	loss 1.43 	accuracy 0.70
# epoch 0 	batch 4600 	loss 1.26 	accuracy 0.60
# epoch 0 	batch 4700 	loss 1.36 	accuracy 0.60
# epoch 0 	batch 4800 	loss 1.37 	accuracy 0.60
# epoch 0 	batch 4900 	loss 0.77 	accuracy 0.80
# Train Accuracy: 49.188%
# Epoch: 0, Loss: 0.14655099508310698
# epoch 1 	batch 0 	loss 1.42 	accuracy 0.20
# epoch 1 	batch 100 	loss 1.29 	accuracy 0.60
# epoch 1 	batch 200 	loss 2.20 	accuracy 0.60
# epoch 1 	batch 300 	loss 1.50 	accuracy 0.50
# epoch 1 	batch 400 	loss 1.47 	accuracy 0.40
# epoch 1 	batch 500 	loss 1.19 	accuracy 0.60
# epoch 1 	batch 600 	loss 1.52 	accuracy 0.60
# epoch 1 	batch 700 	loss 1.08 	accuracy 0.70
# epoch 1 	batch 800 	loss 1.32 	accuracy 0.50
# epoch 1 	batch 900 	loss 1.40 	accuracy 0.50
# epoch 1 	batch 1000 	loss 1.00 	accuracy 0.60
# epoch 1 	batch 1100 	loss 1.25 	accuracy 0.40
# epoch 1 	batch 1200 	loss 0.76 	accuracy 0.80
# epoch 1 	batch 1300 	loss 0.71 	accuracy 0.80
# epoch 1 	batch 1400 	loss 0.74 	accuracy 0.70
# epoch 1 	batch 1500 	loss 0.97 	accuracy 0.70
# epoch 1 	batch 1600 	loss 1.21 	accuracy 0.50
# epoch 1 	batch 1700 	loss 1.19 	accuracy 0.80
# epoch 1 	batch 1800 	loss 1.28 	accuracy 0.50
# epoch 1 	batch 1900 	loss 0.77 	accuracy 0.80
# epoch 1 	batch 2000 	loss 1.06 	accuracy 0.70
# epoch 1 	batch 2100 	loss 1.80 	accuracy 0.30
# epoch 1 	batch 2200 	loss 1.48 	accuracy 0.50
# epoch 1 	batch 2300 	loss 0.92 	accuracy 0.60
# epoch 1 	batch 2400 	loss 1.76 	accuracy 0.40
# epoch 1 	batch 2500 	loss 0.74 	accuracy 0.70
# epoch 1 	batch 2600 	loss 1.29 	accuracy 0.60
# epoch 1 	batch 2700 	loss 1.79 	accuracy 0.40
# epoch 1 	batch 2800 	loss 1.49 	accuracy 0.40
# epoch 1 	batch 2900 	loss 1.27 	accuracy 0.50
# epoch 1 	batch 3000 	loss 1.64 	accuracy 0.20
# epoch 1 	batch 3100 	loss 1.51 	accuracy 0.40
# epoch 1 	batch 3200 	loss 1.20 	accuracy 0.60
# epoch 1 	batch 3300 	loss 1.16 	accuracy 0.70
# epoch 1 	batch 3400 	loss 1.50 	accuracy 0.50
# epoch 1 	batch 3500 	loss 1.45 	accuracy 0.50
# epoch 1 	batch 3600 	loss 1.41 	accuracy 0.60
# epoch 1 	batch 3700 	loss 0.87 	accuracy 0.80
# epoch 1 	batch 3800 	loss 0.95 	accuracy 0.70
# epoch 1 	batch 3900 	loss 0.91 	accuracy 0.70
# epoch 1 	batch 4000 	loss 1.01 	accuracy 0.90
# epoch 1 	batch 4100 	loss 1.36 	accuracy 0.70
# epoch 1 	batch 4200 	loss 1.44 	accuracy 0.50
# epoch 1 	batch 4300 	loss 0.97 	accuracy 0.70
# epoch 1 	batch 4400 	loss 0.58 	accuracy 0.90
# epoch 1 	batch 4500 	loss 1.13 	accuracy 0.70
# epoch 1 	batch 4600 	loss 1.68 	accuracy 0.50
# epoch 1 	batch 4700 	loss 1.24 	accuracy 0.60
# epoch 1 	batch 4800 	loss 1.30 	accuracy 0.70
# epoch 1 	batch 4900 	loss 1.30 	accuracy 0.50
# Train Accuracy: 58.138%
# Epoch: 1, Loss: 0.12189850826771648
# epoch 2 	batch 0 	loss 1.09 	accuracy 0.60
# epoch 2 	batch 100 	loss 1.55 	accuracy 0.30
# epoch 2 	batch 200 	loss 1.25 	accuracy 0.50
# epoch 2 	batch 300 	loss 0.77 	accuracy 0.80
# epoch 2 	batch 400 	loss 1.34 	accuracy 0.30
# epoch 2 	batch 500 	loss 0.72 	accuracy 0.60
# epoch 2 	batch 600 	loss 1.09 	accuracy 0.80
# epoch 2 	batch 700 	loss 1.78 	accuracy 0.30
# epoch 2 	batch 800 	loss 1.25 	accuracy 0.60
# epoch 2 	batch 900 	loss 0.86 	accuracy 0.80
# epoch 2 	batch 1000 	loss 0.90 	accuracy 0.80
# epoch 2 	batch 1100 	loss 1.21 	accuracy 0.50
# epoch 2 	batch 1200 	loss 0.90 	accuracy 0.70
# epoch 2 	batch 1300 	loss 1.51 	accuracy 0.40
# epoch 2 	batch 1400 	loss 1.40 	accuracy 0.40
# epoch 2 	batch 1500 	loss 0.98 	accuracy 0.70
# epoch 2 	batch 1600 	loss 0.70 	accuracy 0.80
# epoch 2 	batch 1700 	loss 0.84 	accuracy 0.70
# epoch 2 	batch 1800 	loss 1.14 	accuracy 0.60
# epoch 2 	batch 1900 	loss 1.05 	accuracy 0.80
# epoch 2 	batch 2000 	loss 0.76 	accuracy 0.70
# epoch 2 	batch 2100 	loss 1.28 	accuracy 0.70
# epoch 2 	batch 2200 	loss 0.86 	accuracy 0.80
# epoch 2 	batch 2300 	loss 1.29 	accuracy 0.40
# epoch 2 	batch 2400 	loss 1.40 	accuracy 0.60
# epoch 2 	batch 2500 	loss 1.74 	accuracy 0.20
# epoch 2 	batch 2600 	loss 0.70 	accuracy 0.70
# epoch 2 	batch 2700 	loss 1.34 	accuracy 0.60
# epoch 2 	batch 2800 	loss 1.30 	accuracy 0.50
# epoch 2 	batch 2900 	loss 0.91 	accuracy 0.70
# epoch 2 	batch 3000 	loss 1.41 	accuracy 0.60
# epoch 2 	batch 3100 	loss 0.86 	accuracy 0.70
# epoch 2 	batch 3200 	loss 1.44 	accuracy 0.70
# epoch 2 	batch 3300 	loss 1.33 	accuracy 0.50
# epoch 2 	batch 3400 	loss 1.22 	accuracy 0.50
# epoch 2 	batch 3500 	loss 0.94 	accuracy 0.70
# epoch 2 	batch 3600 	loss 1.03 	accuracy 0.70
# epoch 2 	batch 3700 	loss 0.76 	accuracy 0.70
# epoch 2 	batch 3800 	loss 1.15 	accuracy 0.70
# epoch 2 	batch 3900 	loss 0.98 	accuracy 0.70
# epoch 2 	batch 4000 	loss 1.10 	accuracy 0.60
# epoch 2 	batch 4100 	loss 0.84 	accuracy 0.80
# epoch 2 	batch 4200 	loss 0.99 	accuracy 0.60
# epoch 2 	batch 4300 	loss 1.76 	accuracy 0.40
# epoch 2 	batch 4400 	loss 1.24 	accuracy 0.50
# epoch 2 	batch 4500 	loss 0.94 	accuracy 0.70
# epoch 2 	batch 4600 	loss 0.83 	accuracy 0.70
# epoch 2 	batch 4700 	loss 0.95 	accuracy 0.60
# epoch 2 	batch 4800 	loss 1.61 	accuracy 0.50
# epoch 2 	batch 4900 	loss 1.22 	accuracy 0.60
# Train Accuracy: 60.726%
# Epoch: 2, Loss: 0.11476709348659103
# epoch 3 	batch 0 	loss 0.78 	accuracy 0.70
# epoch 3 	batch 100 	loss 0.86 	accuracy 0.70
# epoch 3 	batch 200 	loss 1.83 	accuracy 0.50
# epoch 3 	batch 300 	loss 1.21 	accuracy 0.70
# epoch 3 	batch 400 	loss 0.77 	accuracy 0.70
# epoch 3 	batch 500 	loss 0.91 	accuracy 0.80
# epoch 3 	batch 600 	loss 1.32 	accuracy 0.40
# epoch 3 	batch 700 	loss 0.86 	accuracy 0.80
# epoch 3 	batch 800 	loss 1.75 	accuracy 0.40
# epoch 3 	batch 900 	loss 1.16 	accuracy 0.80
# epoch 3 	batch 1000 	loss 1.54 	accuracy 0.70
# epoch 3 	batch 1100 	loss 0.93 	accuracy 0.80
# epoch 3 	batch 1200 	loss 1.67 	accuracy 0.30
# epoch 3 	batch 1300 	loss 1.08 	accuracy 0.60
# epoch 3 	batch 1400 	loss 1.24 	accuracy 0.50
# epoch 3 	batch 1500 	loss 0.86 	accuracy 0.70
# epoch 3 	batch 1600 	loss 1.12 	accuracy 0.50
# epoch 3 	batch 1700 	loss 1.16 	accuracy 0.50
# epoch 3 	batch 1800 	loss 0.93 	accuracy 0.60
# epoch 3 	batch 1900 	loss 1.16 	accuracy 0.50
# epoch 3 	batch 2000 	loss 1.67 	accuracy 0.60
# epoch 3 	batch 2100 	loss 1.64 	accuracy 0.40
# epoch 3 	batch 2200 	loss 1.16 	accuracy 0.50
# epoch 3 	batch 2300 	loss 0.79 	accuracy 0.60
# epoch 3 	batch 2400 	loss 1.11 	accuracy 0.60
# epoch 3 	batch 2500 	loss 1.04 	accuracy 0.60
# epoch 3 	batch 2600 	loss 1.01 	accuracy 0.70
# epoch 3 	batch 2700 	loss 1.13 	accuracy 0.50
# epoch 3 	batch 2800 	loss 0.99 	accuracy 0.50
# epoch 3 	batch 2900 	loss 1.04 	accuracy 0.50
# epoch 3 	batch 3000 	loss 0.71 	accuracy 1.00
# epoch 3 	batch 3100 	loss 0.80 	accuracy 0.70
# epoch 3 	batch 3200 	loss 1.50 	accuracy 0.40
# epoch 3 	batch 3300 	loss 1.15 	accuracy 0.60
# epoch 3 	batch 3400 	loss 0.76 	accuracy 0.80
# epoch 3 	batch 3500 	loss 1.12 	accuracy 0.60
# epoch 3 	batch 3600 	loss 0.32 	accuracy 0.90
# epoch 3 	batch 3700 	loss 0.91 	accuracy 0.70
# epoch 3 	batch 3800 	loss 0.82 	accuracy 0.90
# epoch 3 	batch 3900 	loss 1.45 	accuracy 0.70
# epoch 3 	batch 4000 	loss 1.23 	accuracy 0.80
# epoch 3 	batch 4100 	loss 0.90 	accuracy 0.60
# epoch 3 	batch 4200 	loss 1.06 	accuracy 0.70
# epoch 3 	batch 4300 	loss 1.78 	accuracy 0.40
# epoch 3 	batch 4400 	loss 0.81 	accuracy 0.90
# epoch 3 	batch 4500 	loss 1.52 	accuracy 0.60
# epoch 3 	batch 4600 	loss 0.59 	accuracy 0.80
# epoch 3 	batch 4700 	loss 1.18 	accuracy 0.70
# epoch 3 	batch 4800 	loss 0.93 	accuracy 0.60
# epoch 3 	batch 4900 	loss 1.76 	accuracy 0.30
# Train Accuracy: 62.61%
# Epoch: 3, Loss: 0.11051700701263349
# epoch 4 	batch 0 	loss 1.00 	accuracy 0.60
# epoch 4 	batch 100 	loss 0.71 	accuracy 0.70
# epoch 4 	batch 200 	loss 1.09 	accuracy 0.80
# epoch 4 	batch 300 	loss 0.79 	accuracy 0.60
# epoch 4 	batch 400 	loss 0.67 	accuracy 0.90
# epoch 4 	batch 500 	loss 0.73 	accuracy 0.70
# epoch 4 	batch 600 	loss 1.01 	accuracy 0.80
# epoch 4 	batch 700 	loss 1.05 	accuracy 0.50
# epoch 4 	batch 800 	loss 0.87 	accuracy 0.70
# epoch 4 	batch 900 	loss 1.22 	accuracy 0.50
# epoch 4 	batch 1000 	loss 1.02 	accuracy 0.70
# epoch 4 	batch 1100 	loss 0.89 	accuracy 0.50
# epoch 4 	batch 1200 	loss 0.98 	accuracy 0.60
# epoch 4 	batch 1300 	loss 0.88 	accuracy 0.60
# epoch 4 	batch 1400 	loss 1.00 	accuracy 0.70
# epoch 4 	batch 1500 	loss 1.05 	accuracy 0.70
# epoch 4 	batch 1600 	loss 1.08 	accuracy 0.60
# epoch 4 	batch 1700 	loss 0.74 	accuracy 0.80
# epoch 4 	batch 1800 	loss 0.51 	accuracy 1.00
# epoch 4 	batch 1900 	loss 0.90 	accuracy 0.80
# epoch 4 	batch 2000 	loss 0.79 	accuracy 0.70
# epoch 4 	batch 2100 	loss 0.94 	accuracy 0.70
# epoch 4 	batch 2200 	loss 0.79 	accuracy 0.70
# epoch 4 	batch 2300 	loss 0.75 	accuracy 0.80
# epoch 4 	batch 2400 	loss 0.62 	accuracy 0.80
# epoch 4 	batch 2500 	loss 1.05 	accuracy 0.60
# epoch 4 	batch 2600 	loss 1.42 	accuracy 0.60
# epoch 4 	batch 2700 	loss 0.69 	accuracy 0.90
# epoch 4 	batch 2800 	loss 1.00 	accuracy 0.70
# epoch 4 	batch 2900 	loss 1.07 	accuracy 0.50
# epoch 4 	batch 3000 	loss 0.81 	accuracy 0.70
# epoch 4 	batch 3100 	loss 0.91 	accuracy 0.70
# epoch 4 	batch 3200 	loss 0.97 	accuracy 0.60
# epoch 4 	batch 3300 	loss 1.41 	accuracy 0.50
# epoch 4 	batch 3400 	loss 0.52 	accuracy 0.90
# epoch 4 	batch 3500 	loss 0.99 	accuracy 0.70
# epoch 4 	batch 3600 	loss 0.98 	accuracy 0.60
# epoch 4 	batch 3700 	loss 1.06 	accuracy 0.50
# epoch 4 	batch 3800 	loss 1.36 	accuracy 0.60
# epoch 4 	batch 3900 	loss 1.25 	accuracy 0.50
# epoch 4 	batch 4000 	loss 0.92 	accuracy 0.70
# epoch 4 	batch 4100 	loss 0.88 	accuracy 0.50
# epoch 4 	batch 4200 	loss 1.23 	accuracy 0.70
# epoch 4 	batch 4300 	loss 1.31 	accuracy 0.70
# epoch 4 	batch 4400 	loss 0.72 	accuracy 0.80
# epoch 4 	batch 4500 	loss 1.01 	accuracy 0.60
# epoch 4 	batch 4600 	loss 0.98 	accuracy 0.60
# epoch 4 	batch 4700 	loss 1.43 	accuracy 0.40
# epoch 4 	batch 4800 	loss 1.38 	accuracy 0.60
# epoch 4 	batch 4900 	loss 1.03 	accuracy 0.60
# Train Accuracy: 63.47%
# Epoch: 4, Loss: 0.10777148374402014
# epoch 5 	batch 0 	loss 1.16 	accuracy 0.80
# epoch 5 	batch 100 	loss 0.98 	accuracy 0.70
# epoch 5 	batch 200 	loss 1.15 	accuracy 0.70
# epoch 5 	batch 300 	loss 0.68 	accuracy 0.80
# epoch 5 	batch 400 	loss 1.06 	accuracy 0.50
# epoch 5 	batch 500 	loss 0.62 	accuracy 0.80
# epoch 5 	batch 600 	loss 1.21 	accuracy 0.40
# epoch 5 	batch 700 	loss 1.07 	accuracy 0.50
# epoch 5 	batch 800 	loss 1.66 	accuracy 0.60
# epoch 5 	batch 900 	loss 0.50 	accuracy 0.90
# epoch 5 	batch 1000 	loss 0.93 	accuracy 0.60
# epoch 5 	batch 1100 	loss 0.93 	accuracy 0.50
# epoch 5 	batch 1200 	loss 1.05 	accuracy 0.70
# epoch 5 	batch 1300 	loss 0.94 	accuracy 0.70
# epoch 5 	batch 1400 	loss 0.76 	accuracy 0.80
# epoch 5 	batch 1500 	loss 0.81 	accuracy 0.70
# epoch 5 	batch 1600 	loss 0.91 	accuracy 0.70
# epoch 5 	batch 1700 	loss 0.51 	accuracy 0.90
# epoch 5 	batch 1800 	loss 1.36 	accuracy 0.50
# epoch 5 	batch 1900 	loss 2.07 	accuracy 0.40
# epoch 5 	batch 2000 	loss 1.53 	accuracy 0.60
# epoch 5 	batch 2100 	loss 1.16 	accuracy 0.60
# epoch 5 	batch 2200 	loss 0.47 	accuracy 0.90
# epoch 5 	batch 2300 	loss 1.17 	accuracy 0.60
# epoch 5 	batch 2400 	loss 1.64 	accuracy 0.60
# epoch 5 	batch 2500 	loss 1.01 	accuracy 0.70
# epoch 5 	batch 2600 	loss 0.82 	accuracy 0.80
# epoch 5 	batch 2700 	loss 0.70 	accuracy 0.70
# epoch 5 	batch 2800 	loss 1.04 	accuracy 0.60
# epoch 5 	batch 2900 	loss 1.13 	accuracy 0.70
# epoch 5 	batch 3000 	loss 1.23 	accuracy 0.80
# epoch 5 	batch 3100 	loss 1.53 	accuracy 0.70
# epoch 5 	batch 3200 	loss 1.04 	accuracy 0.80
# epoch 5 	batch 3300 	loss 0.88 	accuracy 0.80
# epoch 5 	batch 3400 	loss 0.61 	accuracy 0.90
# epoch 5 	batch 3500 	loss 0.73 	accuracy 0.90
# epoch 5 	batch 3600 	loss 1.36 	accuracy 0.50
# epoch 5 	batch 3700 	loss 1.18 	accuracy 0.50
# epoch 5 	batch 3800 	loss 1.12 	accuracy 0.70
# epoch 5 	batch 3900 	loss 0.54 	accuracy 0.80
# epoch 5 	batch 4000 	loss 1.30 	accuracy 0.90
# epoch 5 	batch 4100 	loss 1.34 	accuracy 0.50
# epoch 5 	batch 4200 	loss 1.16 	accuracy 0.80
# epoch 5 	batch 4300 	loss 1.19 	accuracy 0.50
# epoch 5 	batch 4400 	loss 1.00 	accuracy 0.70
# epoch 5 	batch 4500 	loss 1.09 	accuracy 0.70
# epoch 5 	batch 4600 	loss 1.37 	accuracy 0.70
# epoch 5 	batch 4700 	loss 1.13 	accuracy 0.60
# epoch 5 	batch 4800 	loss 0.84 	accuracy 0.60
# epoch 5 	batch 4900 	loss 1.69 	accuracy 0.40
# Train Accuracy: 64.428%
# Epoch: 5, Loss: 0.10552917544250122
# epoch 6 	batch 0 	loss 0.73 	accuracy 0.70
# epoch 6 	batch 100 	loss 1.42 	accuracy 0.60
# epoch 6 	batch 200 	loss 1.17 	accuracy 0.40
# epoch 6 	batch 300 	loss 0.85 	accuracy 0.70
# epoch 6 	batch 400 	loss 1.04 	accuracy 0.70
# epoch 6 	batch 500 	loss 0.93 	accuracy 0.80
# epoch 6 	batch 600 	loss 1.58 	accuracy 0.40
# epoch 6 	batch 700 	loss 1.46 	accuracy 0.50
# epoch 6 	batch 800 	loss 1.06 	accuracy 0.60
# epoch 6 	batch 900 	loss 0.65 	accuracy 0.90
# epoch 6 	batch 1000 	loss 0.71 	accuracy 0.80
# epoch 6 	batch 1100 	loss 1.06 	accuracy 0.60
# epoch 6 	batch 1200 	loss 1.18 	accuracy 0.50
# epoch 6 	batch 1300 	loss 1.21 	accuracy 0.50
# epoch 6 	batch 1400 	loss 0.80 	accuracy 0.70
# epoch 6 	batch 1500 	loss 0.85 	accuracy 0.70
# epoch 6 	batch 1600 	loss 1.15 	accuracy 0.50
# epoch 6 	batch 1700 	loss 1.05 	accuracy 0.60
# epoch 6 	batch 1800 	loss 1.42 	accuracy 0.40
# epoch 6 	batch 1900 	loss 0.91 	accuracy 0.60
# epoch 6 	batch 2000 	loss 1.66 	accuracy 0.40
# epoch 6 	batch 2100 	loss 0.88 	accuracy 0.70
# epoch 6 	batch 2200 	loss 0.33 	accuracy 0.90
# epoch 6 	batch 2300 	loss 0.83 	accuracy 0.80
# epoch 6 	batch 2400 	loss 0.89 	accuracy 0.70
# epoch 6 	batch 2500 	loss 0.82 	accuracy 0.90
# epoch 6 	batch 2600 	loss 0.62 	accuracy 0.90
# epoch 6 	batch 2700 	loss 0.59 	accuracy 0.80
# epoch 6 	batch 2800 	loss 1.04 	accuracy 0.70
# epoch 6 	batch 2900 	loss 0.70 	accuracy 0.80
# epoch 6 	batch 3000 	loss 0.91 	accuracy 0.60
# epoch 6 	batch 3100 	loss 1.18 	accuracy 0.70
# epoch 6 	batch 3200 	loss 0.61 	accuracy 0.90
# epoch 6 	batch 3300 	loss 1.19 	accuracy 0.50
# epoch 6 	batch 3400 	loss 0.93 	accuracy 0.70
# epoch 6 	batch 3500 	loss 0.93 	accuracy 0.80
# epoch 6 	batch 3600 	loss 1.49 	accuracy 0.50
# epoch 6 	batch 3700 	loss 1.23 	accuracy 0.60
# epoch 6 	batch 3800 	loss 0.87 	accuracy 0.70
# epoch 6 	batch 3900 	loss 1.06 	accuracy 0.50
# epoch 6 	batch 4000 	loss 1.61 	accuracy 0.30
# epoch 6 	batch 4100 	loss 1.11 	accuracy 0.40
# epoch 6 	batch 4200 	loss 1.47 	accuracy 0.40
# epoch 6 	batch 4300 	loss 1.15 	accuracy 0.70
# epoch 6 	batch 4400 	loss 0.97 	accuracy 0.70
# epoch 6 	batch 4500 	loss 0.84 	accuracy 0.60
# epoch 6 	batch 4600 	loss 0.72 	accuracy 0.80
# epoch 6 	batch 4700 	loss 1.06 	accuracy 0.50
# epoch 6 	batch 4800 	loss 0.81 	accuracy 0.70
# epoch 6 	batch 4900 	loss 0.58 	accuracy 0.80
# Train Accuracy: 64.688%
# Epoch: 6, Loss: 0.10411238186863628
# epoch 7 	batch 0 	loss 1.32 	accuracy 0.60
# epoch 7 	batch 100 	loss 1.13 	accuracy 0.60
# epoch 7 	batch 200 	loss 0.61 	accuracy 0.90
# epoch 7 	batch 300 	loss 0.78 	accuracy 0.80
# epoch 7 	batch 400 	loss 0.60 	accuracy 0.90
# epoch 7 	batch 500 	loss 0.83 	accuracy 0.80
# epoch 7 	batch 600 	loss 0.45 	accuracy 1.00
# epoch 7 	batch 700 	loss 1.25 	accuracy 0.60
# epoch 7 	batch 800 	loss 1.11 	accuracy 0.40
# epoch 7 	batch 900 	loss 0.98 	accuracy 0.70
# epoch 7 	batch 1000 	loss 1.22 	accuracy 0.40
# epoch 7 	batch 1100 	loss 0.68 	accuracy 0.90
# epoch 7 	batch 1200 	loss 1.11 	accuracy 0.50
# epoch 7 	batch 1300 	loss 1.39 	accuracy 0.60
# epoch 7 	batch 1400 	loss 0.85 	accuracy 0.80
# epoch 7 	batch 1500 	loss 0.80 	accuracy 0.70
# epoch 7 	batch 1600 	loss 0.40 	accuracy 0.90
# epoch 7 	batch 1700 	loss 0.79 	accuracy 0.80
# epoch 7 	batch 1800 	loss 0.85 	accuracy 0.70
# epoch 7 	batch 1900 	loss 0.85 	accuracy 0.80
# epoch 7 	batch 2000 	loss 1.50 	accuracy 0.50
# epoch 7 	batch 2100 	loss 1.14 	accuracy 0.60
# epoch 7 	batch 2200 	loss 0.92 	accuracy 0.70
# epoch 7 	batch 2300 	loss 1.20 	accuracy 0.60
# epoch 7 	batch 2400 	loss 0.79 	accuracy 0.70
# epoch 7 	batch 2500 	loss 1.33 	accuracy 0.40
# epoch 7 	batch 2600 	loss 0.87 	accuracy 0.70
# epoch 7 	batch 2700 	loss 1.01 	accuracy 0.60
# epoch 7 	batch 2800 	loss 0.72 	accuracy 0.80
# epoch 7 	batch 2900 	loss 1.04 	accuracy 0.60
# epoch 7 	batch 3000 	loss 0.77 	accuracy 0.70
# epoch 7 	batch 3100 	loss 0.94 	accuracy 0.60
# epoch 7 	batch 3200 	loss 0.96 	accuracy 0.70
# epoch 7 	batch 3300 	loss 1.03 	accuracy 0.70
# epoch 7 	batch 3400 	loss 0.44 	accuracy 0.90
# epoch 7 	batch 3500 	loss 1.15 	accuracy 0.60
# epoch 7 	batch 3600 	loss 0.72 	accuracy 0.70
# epoch 7 	batch 3700 	loss 1.15 	accuracy 0.40
# epoch 7 	batch 3800 	loss 0.86 	accuracy 0.70
# epoch 7 	batch 3900 	loss 0.99 	accuracy 0.80
# epoch 7 	batch 4000 	loss 0.70 	accuracy 0.90
# epoch 7 	batch 4100 	loss 0.51 	accuracy 0.80
# epoch 7 	batch 4200 	loss 0.66 	accuracy 0.90
# epoch 7 	batch 4300 	loss 0.87 	accuracy 0.70
# epoch 7 	batch 4400 	loss 1.27 	accuracy 0.60
# epoch 7 	batch 4500 	loss 0.91 	accuracy 0.80
# epoch 7 	batch 4600 	loss 1.07 	accuracy 0.50
# epoch 7 	batch 4700 	loss 1.09 	accuracy 0.60
# epoch 7 	batch 4800 	loss 0.93 	accuracy 0.60
# epoch 7 	batch 4900 	loss 0.77 	accuracy 0.80
# Train Accuracy: 65.47%
# Epoch: 7, Loss: 0.10276661704983565
# epoch 8 	batch 0 	loss 0.88 	accuracy 0.70
# epoch 8 	batch 100 	loss 0.68 	accuracy 0.80
# epoch 8 	batch 200 	loss 1.36 	accuracy 0.50
# epoch 8 	batch 300 	loss 1.05 	accuracy 0.80
# epoch 8 	batch 400 	loss 0.67 	accuracy 0.80
# epoch 8 	batch 500 	loss 1.15 	accuracy 0.50
# epoch 8 	batch 600 	loss 1.52 	accuracy 0.50
# epoch 8 	batch 700 	loss 0.98 	accuracy 0.70
# epoch 8 	batch 800 	loss 1.17 	accuracy 0.50
# epoch 8 	batch 900 	loss 0.88 	accuracy 0.90
# epoch 8 	batch 1000 	loss 1.12 	accuracy 0.60
# epoch 8 	batch 1100 	loss 1.28 	accuracy 0.60
# epoch 8 	batch 1200 	loss 0.87 	accuracy 0.60
# epoch 8 	batch 1300 	loss 0.45 	accuracy 0.90
# epoch 8 	batch 1400 	loss 0.95 	accuracy 0.80
# epoch 8 	batch 1500 	loss 0.59 	accuracy 0.80
# epoch 8 	batch 1600 	loss 1.25 	accuracy 0.60
# epoch 8 	batch 1700 	loss 0.94 	accuracy 0.40
# epoch 8 	batch 1800 	loss 1.25 	accuracy 0.60
# epoch 8 	batch 1900 	loss 0.90 	accuracy 0.70
# epoch 8 	batch 2000 	loss 1.08 	accuracy 0.60
# epoch 8 	batch 2100 	loss 0.74 	accuracy 0.70
# epoch 8 	batch 2200 	loss 0.79 	accuracy 0.80
# epoch 8 	batch 2300 	loss 0.83 	accuracy 0.70
# epoch 8 	batch 2400 	loss 1.23 	accuracy 0.70
# epoch 8 	batch 2500 	loss 0.91 	accuracy 0.70
# epoch 8 	batch 2600 	loss 0.54 	accuracy 0.80
# epoch 8 	batch 2700 	loss 1.22 	accuracy 0.50
# epoch 8 	batch 2800 	loss 1.08 	accuracy 0.50
# epoch 8 	batch 2900 	loss 1.09 	accuracy 0.60
# epoch 8 	batch 3000 	loss 0.87 	accuracy 0.60
# epoch 8 	batch 3100 	loss 0.78 	accuracy 0.80
# epoch 8 	batch 3200 	loss 1.03 	accuracy 0.50
# epoch 8 	batch 3300 	loss 1.20 	accuracy 0.70
# epoch 8 	batch 3400 	loss 0.73 	accuracy 0.80
# epoch 8 	batch 3500 	loss 1.51 	accuracy 0.60
# epoch 8 	batch 3600 	loss 1.01 	accuracy 0.40
# epoch 8 	batch 3700 	loss 1.17 	accuracy 0.60
# epoch 8 	batch 3800 	loss 2.07 	accuracy 0.40
# epoch 8 	batch 3900 	loss 0.87 	accuracy 0.80
# epoch 8 	batch 4000 	loss 1.18 	accuracy 0.50
# epoch 8 	batch 4100 	loss 0.98 	accuracy 0.70
# epoch 8 	batch 4200 	loss 1.27 	accuracy 0.60
# epoch 8 	batch 4300 	loss 1.05 	accuracy 0.50
# epoch 8 	batch 4400 	loss 0.93 	accuracy 0.60
# epoch 8 	batch 4500 	loss 0.55 	accuracy 0.90
# epoch 8 	batch 4600 	loss 0.70 	accuracy 0.70
# epoch 8 	batch 4700 	loss 1.07 	accuracy 0.60
# epoch 8 	batch 4800 	loss 1.22 	accuracy 0.50
# epoch 8 	batch 4900 	loss 1.18 	accuracy 0.30
# Train Accuracy: 65.758%
# Epoch: 8, Loss: 0.10179483227395054
# epoch 9 	batch 0 	loss 0.86 	accuracy 0.60
# epoch 9 	batch 100 	loss 1.24 	accuracy 0.60
# epoch 9 	batch 200 	loss 0.75 	accuracy 0.70
# epoch 9 	batch 300 	loss 1.14 	accuracy 0.60
# epoch 9 	batch 400 	loss 1.16 	accuracy 0.40
# epoch 9 	batch 500 	loss 1.11 	accuracy 0.70
# epoch 9 	batch 600 	loss 1.28 	accuracy 0.70
# epoch 9 	batch 700 	loss 1.37 	accuracy 0.60
# epoch 9 	batch 800 	loss 0.66 	accuracy 0.90
# epoch 9 	batch 900 	loss 2.09 	accuracy 0.40
# epoch 9 	batch 1000 	loss 1.22 	accuracy 0.60
# epoch 9 	batch 1100 	loss 1.38 	accuracy 0.40
# epoch 9 	batch 1200 	loss 1.33 	accuracy 0.60
# epoch 9 	batch 1300 	loss 1.06 	accuracy 0.70
# epoch 9 	batch 1400 	loss 0.65 	accuracy 0.90
# epoch 9 	batch 1500 	loss 1.39 	accuracy 0.40
# epoch 9 	batch 1600 	loss 1.02 	accuracy 0.70
# epoch 9 	batch 1700 	loss 0.96 	accuracy 0.60
# epoch 9 	batch 1800 	loss 0.73 	accuracy 0.80
# epoch 9 	batch 1900 	loss 0.78 	accuracy 0.80
# epoch 9 	batch 2000 	loss 0.91 	accuracy 0.70
# epoch 9 	batch 2100 	loss 1.13 	accuracy 0.60
# epoch 9 	batch 2200 	loss 1.26 	accuracy 0.60
# epoch 9 	batch 2300 	loss 1.00 	accuracy 0.60
# epoch 9 	batch 2400 	loss 1.95 	accuracy 0.50
# epoch 9 	batch 2500 	loss 1.00 	accuracy 0.60
# epoch 9 	batch 2600 	loss 1.29 	accuracy 0.50
# epoch 9 	batch 2700 	loss 0.57 	accuracy 0.80
# epoch 9 	batch 2800 	loss 1.04 	accuracy 0.60
# epoch 9 	batch 2900 	loss 1.63 	accuracy 0.60
# epoch 9 	batch 3000 	loss 1.60 	accuracy 0.60
# epoch 9 	batch 3100 	loss 1.34 	accuracy 0.40
# epoch 9 	batch 3200 	loss 0.85 	accuracy 0.60
# epoch 9 	batch 3300 	loss 0.49 	accuracy 0.80
# epoch 9 	batch 3400 	loss 0.87 	accuracy 0.70
# epoch 9 	batch 3500 	loss 0.69 	accuracy 0.70
# epoch 9 	batch 3600 	loss 1.29 	accuracy 0.40
# epoch 9 	batch 3700 	loss 0.65 	accuracy 0.80
# epoch 9 	batch 3800 	loss 1.32 	accuracy 0.60
# epoch 9 	batch 3900 	loss 0.73 	accuracy 0.80
# epoch 9 	batch 4000 	loss 1.00 	accuracy 0.70
# epoch 9 	batch 4100 	loss 1.73 	accuracy 0.50
# epoch 9 	batch 4200 	loss 1.16 	accuracy 0.60
# epoch 9 	batch 4300 	loss 1.04 	accuracy 0.50
# epoch 9 	batch 4400 	loss 0.55 	accuracy 0.90
# epoch 9 	batch 4500 	loss 0.75 	accuracy 0.80
# epoch 9 	batch 4600 	loss 1.01 	accuracy 0.70
# epoch 9 	batch 4700 	loss 0.57 	accuracy 0.80
# epoch 9 	batch 4800 	loss 0.90 	accuracy 0.70
# epoch 9 	batch 4900 	loss 1.09 	accuracy 0.50
# Train Accuracy: 66.276%
# Epoch: 9, Loss: 0.10098932714317291

# %%
paddle.save(model.state_dict(), "train1.model")

# %%
m = MyCNN()
m.set_state_dict(paddle.load("train1.model"))
m.eval()
eval_loader = paddle.io.DataLoader(
    Reader("../data/cifar-10-batches-py/test_batch"), batch_size=1000, shuffle=True
)

accs = []
for i, (x, y) in enumerate(eval_loader):
    y_pred = m(x)
    mask = np.array(y_pred, copy=False).argmax(1) == y
    acc = mask.sum().numpy() / batch
    print(i, acc)
    accs.append(acc)
print(np.mean(accs))
# Out:
# 0 59.8
# 1 62.0
# 2 61.0
# 3 64.3
# 4 65.7
# 5 62.1
# 6 66.1
# 7 61.0
# 8 63.5
# 9 63.1
# 62.86
